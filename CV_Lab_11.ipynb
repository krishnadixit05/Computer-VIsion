# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnadixit05/Computer-VIsion/blob/main/CV_Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import color, io
from skimage.feature import hog
import matplotlib.pyplot as plt

# %%
# Load and convert image to grayscale
image = io.imread('/content/image (1).JPG')
gray_image = color.rgb2gray(image)

# %%
# Compute HOG and get visualization
features, hog_image = hog(gray_image,
                          orientations=9,
                          pixels_per_cell=(8, 8),
                          cells_per_block=(2, 2),
                          visualize=True,
                          block_norm='L2-Hys')

print("HOG feature vector length:", len(features))
# Out:
# HOG feature vector length: 413028

# %%
# Display original and HOG image
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1199.5), np.float64(629.5), np.float64(-0.5))

# %%
plt.subplot(1, 2, 2)
plt.title("HOG Visualization")
plt.imshow(hog_image, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot histogram of HOG features
plt.subplot(1, 3, 3)
plt.title("Histogram of HOG Features")
plt.hist(features, bins=50, color='orange', edgecolor='black')
plt.xlabel("Feature Value")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
