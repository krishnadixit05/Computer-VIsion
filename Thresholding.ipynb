# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("/Users/krish/Pictures/Me.jpg")

# %%
plt.imshow(img)

# %%
img = cv2.imread("/Users/krish/Pictures/Me.jpg",0)

# %%
plt.imshow(img,cmap='gray')

# %%
lim,img1 = cv2.threshold(img, 100,255,cv2.THRESH_BINARY)

# %%
plt.imshow(img1,cmap='gray')

# %%
lim,img2 = cv2.threshold(img, 100,255,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(img2,cmap='gray')

# %%
lim,img3 = cv2.threshold(img, 100,255,cv2.THRESH_TRUNC)
plt.imshow(img3,cmap='gray')

# %%
lim,img4 = cv2.threshold(img, 100,255,cv2.THRESH_TOZERO)
plt.imshow(img4,cmap='gray')

# %%
lim,img5 = cv2.threshold(img, 100,255,cv2.THRESH_TOZERO_INV)
plt.imshow(img5,cmap='gray')

# %%
lim,img6 = cv2.threshold(img, 100,255,cv2.THRESH_TRUNC)
plt.imshow(img6,cmap='gray')

# %%
lim,img6 = cv2.threshold(img, 20,255,cv2.THRESH_TRUNC) #it showing the difference by changing the threshold value
plt.imshow(img6,cmap='gray')

# %%
lim,img6 = cv2.threshold(img, 200,255,cv2.THRESH_TRUNC)
plt.imshow(img6,cmap='gray')
