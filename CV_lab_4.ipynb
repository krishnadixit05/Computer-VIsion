# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnadixit05/Computer-VIsion/blob/main/CV_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Shi-Tomasi corner detection

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img= cv2.imread("/content/Chessboard.jpg")
img=cv2.resize(img,(0,0),fx=0.75,fy=0.75)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=900x900>

# %%
corners=cv2.goodFeaturesToTrack(gray,150,0.01,50)

# %%
corners
# Out:
# array([[[450., 450.]],
#
#        [[449., 561.]],
#
#        [[450., 338.]],
#
#        [[338., 450.]],
#
#        [[561., 449.]],
#
#        [[339., 560.]],
#
#        [[560., 339.]],
#
#        [[560., 560.]],
#
#        [[339., 339.]],
#
#        [[450., 672.]],
#
#        [[672., 450.]],
#
#        [[227., 450.]],
#
#        [[450., 227.]],
#
#        [[116., 450.]],
#
#        [[783., 449.]],
#
#        [[449., 783.]],
#
#        [[450., 116.]],
#
#        [[560., 671.]],
#
#        [[339., 228.]],
#
#        [[671., 560.]],
#
#        [[228., 339.]],
#
#        [[339., 671.]],
#
#        [[560., 228.]],
#
#        [[228., 560.]],
#
#        [[671., 339.]],
#
#        [[671., 671.]],
#
#        [[228., 228.]],
#
#        [[228., 671.]],
#
#        [[671., 228.]],
#
#        [[783., 561.]],
#
#        [[116., 338.]],
#
#        [[783., 338.]],
#
#        [[116., 561.]],
#
#        [[782., 671.]],
#
#        [[117., 228.]],
#
#        [[561., 783.]],
#
#        [[338., 116.]],
#
#        [[671., 782.]],
#
#        [[228., 117.]],
#
#        [[117., 671.]],
#
#        [[782., 228.]],
#
#        [[339., 783.]],
#
#        [[560., 116.]],
#
#        [[228., 782.]],
#
#        [[671., 117.]],
#
#        [[782., 782.]],
#
#        [[117., 782.]],
#
#        [[782., 117.]],
#
#        [[117., 117.]],
#
#        [[  6., 451.]],
#
#        [[893., 448.]],
#
#        [[448., 893.]],
#
#        [[451.,   6.]],
#
#        [[671., 893.]],
#
#        [[228.,   6.]],
#
#        [[893., 671.]],
#
#        [[  6., 228.]],
#
#        [[339., 893.]],
#
#        [[560.,   6.]],
#
#        [[  6., 560.]],
#
#        [[893., 339.]],
#
#        [[  6., 782.]],
#
#        [[893., 117.]],
#
#        [[117., 893.]],
#
#        [[782.,   6.]],
#
#        [[893., 893.]],
#
#        [[  6.,   6.]],
#
#        [[893., 562.]],
#
#        [[  6., 337.]],
#
#        [[  6., 673.]],
#
#        [[893., 226.]],
#
#        [[226., 893.]],
#
#        [[673.,   6.]],
#
#        [[562., 893.]],
#
#        [[337.,   6.]],
#
#        [[784., 893.]],
#
#        [[115.,   6.]],
#
#        [[893., 784.]],
#
#        [[  6., 115.]]], dtype=float32)

# %%
corners=np.int0(corners)
# Out:
# <ipython-input-5-107069f38cc2>:1: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners=np.int0(corners)

# %%
corners
# Out:
# array([[[450, 450]],
#
#        [[449, 561]],
#
#        [[450, 338]],
#
#        [[338, 450]],
#
#        [[561, 449]],
#
#        [[339, 560]],
#
#        [[560, 339]],
#
#        [[560, 560]],
#
#        [[339, 339]],
#
#        [[450, 672]],
#
#        [[672, 450]],
#
#        [[227, 450]],
#
#        [[450, 227]],
#
#        [[116, 450]],
#
#        [[783, 449]],
#
#        [[449, 783]],
#
#        [[450, 116]],
#
#        [[560, 671]],
#
#        [[339, 228]],
#
#        [[671, 560]],
#
#        [[228, 339]],
#
#        [[339, 671]],
#
#        [[560, 228]],
#
#        [[228, 560]],
#
#        [[671, 339]],
#
#        [[671, 671]],
#
#        [[228, 228]],
#
#        [[228, 671]],
#
#        [[671, 228]],
#
#        [[783, 561]],
#
#        [[116, 338]],
#
#        [[783, 338]],
#
#        [[116, 561]],
#
#        [[782, 671]],
#
#        [[117, 228]],
#
#        [[561, 783]],
#
#        [[338, 116]],
#
#        [[671, 782]],
#
#        [[228, 117]],
#
#        [[117, 671]],
#
#        [[782, 228]],
#
#        [[339, 783]],
#
#        [[560, 116]],
#
#        [[228, 782]],
#
#        [[671, 117]],
#
#        [[782, 782]],
#
#        [[117, 782]],
#
#        [[782, 117]],
#
#        [[117, 117]],
#
#        [[  6, 451]],
#
#        [[893, 448]],
#
#        [[448, 893]],
#
#        [[451,   6]],
#
#        [[671, 893]],
#
#        [[228,   6]],
#
#        [[893, 671]],
#
#        [[  6, 228]],
#
#        [[339, 893]],
#
#        [[560,   6]],
#
#        [[  6, 560]],
#
#        [[893, 339]],
#
#        [[  6, 782]],
#
#        [[893, 117]],
#
#        [[117, 893]],
#
#        [[782,   6]],
#
#        [[893, 893]],
#
#        [[  6,   6]],
#
#        [[893, 562]],
#
#        [[  6, 337]],
#
#        [[  6, 673]],
#
#        [[893, 226]],
#
#        [[226, 893]],
#
#        [[673,   6]],
#
#        [[562, 893]],
#
#        [[337,   6]],
#
#        [[784, 893]],
#
#        [[115,   6]],
#
#        [[893, 784]],
#
#        [[  6, 115]]])

# %%
for corner in corners:
  x,y=corner.ravel()
  cv2.circle(img,(x,y),5,(0,0,255),-1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=900x900>
