# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("/Users/krish/Pictures/flower.jpeg")

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img1.shape
# Out:
# (200, 200, 3)

# %%
img1_resize = cv2.resize(img1,(500,1000))

# %%
plt.imshow(img1_resize)

# %%
new_img1 = cv2.resize(img1,(0,0),img1,0.5,0.5)

# %%
plt.imshow(new_img1)

# %%
new_img1 = cv2.resize(img1,(10,1),img1,0.5,0.5)
plt.imshow(new_img1)

# %%
new_img1 = cv2.resize(img1,(10,10),img1,0.5,0.5)

# %%
plt.imshow(new_img1)

# %%
new_img1 = cv2.resize(img1,(100,100),img1,0.5,0.5)

# %%
plt.imshow(new_img1)

# %%
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img1_flip = cv2.flip(new_img1,0)
plt.imshow(img1_flip)

# %%
img1_flip = cv2.flip(new_img1,1)
plt.imshow(img1_flip)
