# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnadixit05/Computer-VIsion/blob/main/CV_post_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sudoku

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img= cv2.imread("/content/sudoku.jpg")
img=cv2.resize(img,(0,0),fx=1,fy=1)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=254x241>

# %%
corners=cv2.goodFeaturesToTrack(gray,150,0.01,50)

# %%
corners
# Out:
# array([[[ 84.,  55.]],
#
#        [[224.,   5.]],
#
#        [[ 88., 212.]],
#
#        [[224., 162.]],
#
#        [[ 88., 108.]],
#
#        [[  5.,  55.]],
#
#        [[166., 212.]],
#
#        [[249., 212.]],
#
#        [[141., 158.]],
#
#        [[ 30., 236.]],
#
#        [[166.,  29.]],
#
#        [[249.,  79.]],
#
#        [[  5., 158.]],
#
#        [[ 84., 158.]],
#
#        [[ 88.,   5.]],
#
#        [[170., 108.]],
#
#        [[  5.,   5.]],
#
#        [[ 32., 110.]]], dtype=float32)

# %%
corners=np.int0(corners)
# Out:
# <ipython-input-19-107069f38cc2>:1: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners=np.int0(corners)

# %%
corners
# Out:
# array([[[ 84,  55]],
#
#        [[224,   5]],
#
#        [[ 88, 212]],
#
#        [[224, 162]],
#
#        [[ 88, 108]],
#
#        [[  5,  55]],
#
#        [[166, 212]],
#
#        [[249, 212]],
#
#        [[141, 158]],
#
#        [[ 30, 236]],
#
#        [[166,  29]],
#
#        [[249,  79]],
#
#        [[  5, 158]],
#
#        [[ 84, 158]],
#
#        [[ 88,   5]],
#
#        [[170, 108]],
#
#        [[  5,   5]],
#
#        [[ 32, 110]]])

# %%
for corner in corners:
  x,y=corner.ravel()
  cv2.circle(img,(x,y),5,(0,0,255),-1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=254x241>
