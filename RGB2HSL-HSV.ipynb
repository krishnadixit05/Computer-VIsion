# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/Users/krish/Pictures/Me.jpg")

# %%
plt.imshow(img)

# %%
pic = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %%
pic1 = cv2.cvtColor(pic, cv2.COLOR_BGR2HSV)
plt.imshow(pic1)

# %%
pic2 = cv2.cvtColor(pic, cv2.COLOR_BGR2HLS)
plt.imshow(pic2)

# %%
pic3 = cv2.cvtColor(pic, cv2.COLOR_BGR2HSV)
plt.imshow(pic3)

# %%
pic4 = cv2.cvtColor(pic, cv2.COLOR_BGR2HLS)
plt.imshow(pic4)
