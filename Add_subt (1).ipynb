# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread("/Users/krish/Pictures/satellite.jpeg")

# %%
plt.imshow(img1)

# %%
img2 = cv2.imread("/Users/krish/Pictures/satellite.jpeg")

# %%
plt.imshow(img2)

# %%
add_img = cv2.add(img1,img2)
plt.imshow(add_img)

# %%
weightedimg = cv2.addWeighted(img1, 0.5, img2, 0.4, 0)
plt.imshow(cv2.cvtColor(weightedimg, cv2.COLOR_BGR2RGB))
