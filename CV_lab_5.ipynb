# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnadixit05/Computer-VIsion/blob/main/CV_lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Template Matching

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
from tempfile import template
img=cv2.imread("/content/Soccer.jpg",0)
img=cv2.resize(img,(0,0),fx=0.8,fy=0.8)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=960x895>

# %%
template=cv2.imread("/content/Ball.jpg",0)
template=cv2.resize(template,(0,0),fx=0.8,fy=0.8)
cv2_imshow(template)
# Out:
# <PIL.Image.Image image mode=L size=99x100>

# %%
method=cv2.TM_CCOEFF_NORMED
img2=img.copy()
result=cv2.matchTemplate(img2,template,method)

# %%
result
# Out:
# array([[-0.04487308, -0.05437391, -0.06186604, ...,  0.04977207,
#          0.05159343,  0.05529999],
#        [-0.06625852, -0.07712528, -0.08589084, ...,  0.04109955,
#          0.04245503,  0.04576008],
#        [-0.08504401, -0.09750388, -0.10769429, ...,  0.03239803,
#          0.03329401,  0.03615745],
#        ...,
#        [ 0.04328793,  0.04575973,  0.04786041, ...,  0.12247348,
#          0.12242554,  0.11923258],
#        [ 0.04646493,  0.04827439,  0.05021067, ...,  0.12716259,
#          0.12789978,  0.12607738],
#        [ 0.05076025,  0.05082899,  0.05198183, ...,  0.13085821,
#          0.13062297,  0.12887388]], dtype=float32)

# %%
min_val,max_val,min_loc,max_loc=cv2.minMaxLoc(result)
location=max_loc

# %%
h,w = template.shape

# %%
bottom_right = (location[0] + w, location[1] + h)
cv2.rectangle(img2, location, bottom_right, (255, 255, 255), 5)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=960x895>
